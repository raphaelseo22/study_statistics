# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
m_heights_mean = 69.1
m_heights_std = 2.9
w_heights_mean = 63.7
w_heights_std = 2.7

# %% [markdown]
# ### Men heights

# %%
print(m_heights_mean + 2 * m_heights_std)
# Out:
# 74.89999999999999

# %%
m_rv = norm(loc = m_heights_mean, scale = m_heights_std)

# %%
m_rv.ppf(0.978)
# Out:
# 74.9408633548526

# %%
m_random_v1 = m_rv.rvs(1000, random_state=0).round(1)
m_random_v2 = m_rv.rvs(1000, random_state=1).round(1)
m_random_v3 = m_rv.rvs(1000, random_state=2).round(1)

# %%
plt.plot(norm.pdf(m_random_v1, loc = m_heights_mean, scale = m_heights_std))

# %%
plt.hist(m_random_v1, density=True, bins="auto", histtype="stepfilled", alpha=0.2)
plt.legend(loc="best", frameon=False)
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(m_random_v2, density=True, bins="auto", histtype="stepfilled", alpha=0.2)
plt.legend(loc="best", frameon=False)
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(m_random_v3, density=True, bins="auto", histtype="stepfilled", alpha=0.2)
plt.legend(loc="best", frameon=False)
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Women heights

# %%
print(w_heights_mean + 2 * w_heights_std)
# Out:
# 69.10000000000001

# %%
w_rv = norm(loc = w_heights_mean, scale = w_heights_std)

# %%
w_rv.ppf(0.978)
# Out:
# 69.13804519244898

# %%
w_random_v1 = w_rv.rvs(1000, random_state=0).round(1)
w_random_v2 = w_rv.rvs(1000, random_state=1).round(1)
w_random_v3 = w_rv.rvs(1000, random_state=2).round(1)
